# %% [markdown]
# # Multithreding = Multiple Threads

# %%
def print_messaege():
    print("Welcome To ETLHIVE")

# %%
import threading

def print_message():
    print("Hello, this is a thread message!")

t1 = threading.Thread(target=print_message)
t1.start()
# Out:
# Hello, this is a thread message!

# %%
# Example 2

# %%
def calculat_square(n):
    print(f"The square of Number{n} is {n*n} ")

# %%
import threading

def calculate_square(n):
    print("Square:", n*n)

t2 = threading.Thread(target=calculate_square, args=(5,))
t2.start()
# Out:
# Square: 25

# %%
l1=[10,20,30,40,500,60,70,80,90,100]

# %%
for i in l1:
    t2=threading.Thread(target=calculate_square,args=(i,))
    t2.start()
# Out:
# Square: 100
# Square: 400
# Square: 900
# Square: 1600
# Square: 250000
# Square: 3600
# Square: 4900
# Square: 6400
# Square: 8100
# Square: 10000

# %%
# create threading for downdloding a file from server

# %%
message="India Is My Country"

# %%
len(message)
# Out:
# 19

# %%
message.split(' ')
# Out:
# ['India', 'Is', 'My', 'Country']

# %%
m = [10, 20, 30, 40]
print(len(m))
# Out:
# 4

# %%
lnk=("https://raw.githubusercontent.com/utkarshg1/mlproject_regression/main/artifacts/data.csv")
len(lnk)
l=lnk.split("/")
len(l)
# Out:
# 8

# %%
l[-1]
# Out:
# 'data.csv'

# %%
import urllib.request
def download_file(lnk):
    file_name=lnk.split("/")[-1]
    print("file is downloading........")
    path="C:/Users/Administrator/Downloads/"+file_name
    urllib.request.urlretrieve(lnk,path)
    print(f"{file_name} is downloading")

# %%
download_file("https://raw.githubusercontent.com/utkarshg1/mlproject_regression/main/artifacts/data.csv")
# Out:
# file is downloading........
# data.csv is downloading

# %%
import threading
import urllib.request

def download_file(lnk):
    file_name = lnk.split("/")[-1]
    print("file is downloading........")
    path = "C:/Users/Administrator/Downloads/" + file_name
    urllib.request.urlretrieve(lnk, path)
    print(f"{file_name} is downloaded")

link = "https://raw.githubusercontent.com/utkarshg1/mlproject_regression/main/artifacts/test.csv"

t1 = threading.Thread(target=download_file, args=(link,))
t1.start()
# Out:
# file is downloading........
# test.csv is downloaded

# %%
import threading
import urllib.request

def download_file(lnk):
    file_name = lnk.split("/")[-1]
    print("file is downloading........")
    path = "C:/Users/Administrator/Downloads/" + file_name
    urllib.request.urlretrieve(lnk, path)
    print(f"{file_name} is downloaded")

link = "https://raw.githubusercontent.com/utkarshg1/mlproject_regression/main/artifacts/train.csv"

t2 = threading.Thread(target=download_file, args=(link,))
t2.start()
# Out:
# file is downloading........
# train.csv is downloaded
